# %% [markdown]
# <a href="https://colab.research.google.com/github/Katla19/Network-Anomaly-Detection/blob/main/Netowkanomaly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
https://docs.google.com/document/d/1LCHFUQ0cULGp1zC7MrfVBTWWmnZ4L9zgYsULVCdOo5g/edit?tab=t.0

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('n.csv')
display(df.head())
# Out:
#    duration protocoltype   service flag  srcbytes  dstbytes  land  \
# 0         0          tcp  ftp_data   SF       491         0     0
# 1         0          udp     other   SF       146         0     0
# 2         0          tcp   private   S0         0         0     0
# 3         0          tcp      http   SF       232      8153     0
# 4         0          tcp      http   SF       199       420     0
#
#    wrongfragment  urgent  hot  ...  dsthostsamesrvrate  dsthostdiffsrvrate  \
# 0              0       0    0  ...                0.17                0.03
# 1              0       0    0  ...                0.00                0.60
# 2              0       0    0  ...                0.10                0.05
# 3              0       0    0  ...                1.00                0.00
# 4              0       0    0  ...                1.00                0.00
#
#    dsthostsamesrcportrate  dsthostsrvdiffhostrate  dsthostserrorrate  \
# ...

# %%
display(df.duplicated().sum())
# Out:
# np.int64(0)

# %%
print(df[df.isnull().any(axis=1)])
# Out:
#         duration protocoltype   service flag  srcbytes  dstbytes  land  \
# 119259         0          tcp  ftp_data  REJ         0         0     0
#
#         wrongfragment  urgent  hot  ...  dsthostsamesrvrate  \
# 119259              0       0    0  ...                 NaN
#
#         dsthostdiffsrvrate  dsthostsamesrcportrate  dsthostsrvdiffhostrate  \
# 119259                 NaN                     NaN                     NaN
#
#         dsthostserrorrate  dsthostsrvserrorrate  dsthostrerrorrate  \
# 119259                NaN                   NaN                NaN
#
#         dsthostsrvrerrorrate  attack  lastflag
# 119259                   NaN     NaN       NaN
#
# [1 rows x 43 columns]

# %%
df.dropna(inplace=True)
print(df.isnull().sum())
# Out:
# duration                  0
# protocoltype              0
# service                   0
# flag                      0
# srcbytes                  0
# dstbytes                  0
# land                      0
# wrongfragment             0
# urgent                    0
# hot                       0
# numfailedlogins           0
# loggedin                  0
# numcompromised            0
# rootshell                 0
# suattempted               0
# numroot                   0
# numfilecreations          0
# numshells                 0
# numaccessfiles            0
# numoutboundcmds           0
# ishostlogin               0
# isguestlogin              0
# count                     0
# srvcount                  0
# serrorrate                0
# srvserrorrate             0
# rerrorrate                0
# srvrerrorrate             0
# samesrvrate               0
# diffsrvrate               0
# srvdiffhostrate           0
# dsthostcount              0
# dsthostsrvcount           0
# ...

# %%
df.shape
# Out:
# (119260, 43)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119260 entries, 0 to 119259
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   duration                119260 non-null  int64
#  1   protocoltype            119260 non-null  object
#  2   service                 119260 non-null  object
#  3   flag                    119260 non-null  object
#  4   srcbytes                119260 non-null  int64
#  5   dstbytes                119260 non-null  int64
#  6   land                    119260 non-null  int64
#  7   wrongfragment           119260 non-null  int64
#  8   urgent                  119260 non-null  int64
#  9   hot                     119260 non-null  int64
#  10  numfailedlogins         119260 non-null  int64
#  11  loggedin                119260 non-null  int64
#  12  numcompromised          119259 non-null  float64
#  13  rootshell               119259 non-null  float64
# ...

# %%
df.describe()
# Out:
#             duration      srcbytes      dstbytes           land  \
# count  119260.000000  1.192600e+05  1.192600e+05  119260.000000
# mean      286.648407  3.598294e+04  2.070917e+04       0.000201
# std      2597.162549  4.520036e+06  4.132852e+06       0.014185
# min         0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%         0.000000  0.000000e+00  0.000000e+00       0.000000
# 50%         0.000000  4.400000e+01  0.000000e+00       0.000000
# 75%         0.000000  2.760000e+02  5.132500e+02       0.000000
# max     42908.000000  1.167519e+09  1.309937e+09       1.000000
#
#        wrongfragment         urgent            hot  numfailedlogins  \
# count  119260.000000  119260.000000  119260.000000    119260.000000
# mean        0.022849       0.000117       0.203480         0.001191
# std         0.254538       0.014765       2.141858         0.045402
# min         0.000000       0.000000       0.000000         0.000000
# ...

# %%
for col in df.columns:
    print(f"Value counts for column: {col}")
    display(df[col].value_counts())
    print("-" * 30)
# Out:
# Value counts for column: duration
# duration
# 0        109788
# 1          1881
# 2           809
# 3           522
# 4           327
#           ...
# 10844         1
# 36224         1
# 6323          1
# 3483          1
# 6650          1
# Name: count, Length: 2841, dtype: int64
# ------------------------------
# Value counts for column: protocoltype
# protocoltype
# tcp     97188
# udp     14234
# icmp     7838
# Name: count, dtype: int64
# ------------------------------
# Value counts for column: service
# service
# http         38154
# private      20710
# domain_u      8590
# smtp          6916
# ftp_data      6518
#              ...
# tftp_u           3
# http_8001        2
# aol              2
# http_2784        1
# harvest          1
# Name: count, Length: 70, dtype: int64
# ------------------------------
# Value counts for column: flag
# flag
# SF        70960
# S0        32984
# REJ       10645
# RSTR       2290
# RSTO       1475
# S1          352
# SH          247
# ...
